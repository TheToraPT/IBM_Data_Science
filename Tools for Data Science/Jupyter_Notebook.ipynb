# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Diogo Mendonça**

# %% [markdown]
# I am interested in data science because of its adaptability to multiple industries.

# %% [markdown]
# ### 1+1=2?

# %%
1+1
# Out:
# 2

# %% [markdown]
# [link](https://external-content.duckduckgo.com/iu/?u=https%3A%2F%2Fmedia.giphy.com%2Fmedia%2F4c0sdgYcz9mpO%2Fgiphy.gif&f=1&nofb=1&ipt=3b4c0f71ad26f26ebeb93c551f9b320ea86fb257665028fc28a300c16f37a894&ipo=images)
#
# ***
# * yes
# ---
# * no
# ___
#
# * maybe
#
# ![imagem.png](attachment:63fdfae3-a2f2-4edd-824a-a12d9b57c80d.png)
